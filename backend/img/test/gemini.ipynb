# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
# !pip install langchain-teddynote

# %%
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("StoryPocket")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# StoryPocket

# %%
chat = """
**할아버지와의 특별한 이야기**

옛날 옛적, 대한민국의 한 작은 마을에 사는 소년 민수는 할아버지를 사랑했습니다. 어느 화창한 날, 민수는 할아버지의 집에 찾아가 이렇게 인사했습니다.

"할아버지! 안녕하세요! 오늘 뭐 하셨어요?"

할아버지는 미소를 지으며 대답했습니다. "오늘은 그냥 집에서 쉬면서 옛날 생각을 좀 했지."

"할아버지, 옛날 생각이 나면 어떤 일이 많이 떠오르세요? 재밌는 이야기 있으면 들려줘요! 어떤 시절이 제일 기억에 남나요?"

할아버지는 잠시 생각에 잠기더니, 이렇게 말했습니다. "오늘은 내가 초등학교 1학년 때 겪었던 일을 얘기해줄까? 그때는 전쟁이 일어났던 시절이었단다."

민수는 놀라며 물었습니다. "와, 할아버지! 초등학교 1학년 때 전쟁이 있었던 거예요? 그때 어떤 일이 있었는지 궁금해요! 친구들은 어땠고, 할아버지는 어떻게 지냈는지 다 들려주세요!"

할아버지는 깊은 한숨을 내쉬며 이야기하기 시작했습니다. "그때는 6.25 전쟁이 터졌지. 나는 학교를 다니던 중이었는데, 갑자기 전쟁이 일어난 거야. 아버지는 군인이셔서 부대에 계셨고, 나는 만삭인 어머니와 외삼촌과 함께 피난을 가야 했단다. 서울에서 남쪽으로, 어머니 고향인 완주 고산으로 피난을 갔지."

"어머, 할아버지! 6.25 전쟁이 일어났을 때 피난을 갔던 거구나!" 민수는 큰 눈을 뜨고 말했습니다. "그때 서울에서 완주 고산까지 가는 길은 어땠어요? 피난 가는 동안 무서운 일도 많았을 것 같아요. 어머니랑 외삼촌이랑 함께해서 조금은 마음이 놓였나요? 그때의 기억이 정말 궁금해요!"

"무서웠지." 할아버지는 대답했습니다. "다리가 무너지면서 더 이상 서울로 돌아갈 수 없다는 생각에 너무 겁이 났어. 그런데도 우리는 계속 걸었어. 가끔 마을을 지나가다 밥을 얻어먹으려고 하면, 집집마다 다 거절당했지. 그 집들도 먹을 게 없었거든."

"할아버지, 그때 정말 무서웠겠어요!" 민수는 마음이 아팠습니다. "다리가 무너져서 돌아갈 수 없다는 생각은 얼마나 힘들었을까요. 계속 걷는 것도 정말 어려웠을 것 같은데, 그때 어떻게 힘을 냈어요? 그리고 밥을 얻어먹으려고 했는데도 거절당했다니, 그 집들도 정말 힘든 상황이었을 것 같아요. 그럼 그 후에 도착한 곳에서는 어떤 일이 있었나요? 잘 지낼 수 있었나요?"

"한 번은 너무 배고파서 길가 과수원에서 새파란 포도를 따 먹었단다." 할아버지는 웃으며 말했습니다. "근데 그게 덜 익어서 먹고 나서 배탈이 나고 설사도 하고, 고생 좀 했지."

"아이고, 할아버지!" 민수는 놀라며 말했습니다. "배고파서 포도를 따 먹었다니, 그거 정말 힘들었겠어요! 덜 익은 포도를 먹고 배탈이 났다니, 얼마나 아팠을까요? 그때는 어떻게 했어요? 어머니와 외삼촌이 도와줬나요? 그런 어려운 상황에서도 포도를 먹으려고 한 할아버지의 용기는 정말 대단해요! 그 후에는 어떻게 지냈는지 더 궁금해요!"

"충청도쯤 가서 한 어르신이 시커먼 꽁보리밥이랑 감자를 주셔서 그걸 먹고 한 끼를 해결했단다. 그때 그분이 참 고마웠어." 할아버지는 따뜻한 미소를 지었습니다.

"와, 할아버지! 충청도에서 어르신이 주신 꽁보리밥과 감자로 한 끼를 해결하셨군요!" 민수는 감탄했습니다. "그 어르신은 정말 따뜻한 마음을 가지신 분이었네요. 고마운 사람과의 기억은 언제나 특별한 것 같아요. 그때 그 어르신과의 이야기도 더 궁금해요! 할아버지는 그 어르신에게 감사 인사를 전했나요? 그리고 그 후에는 어떻게 계속 피난 생활을 하셨는지 더 듣고 싶어요!"

"그 이후는 잘 기억이 안 나. 이래저래 살다 보니 벌써 시간이 이렇게 됐구나." 할아버지는 아쉬운 듯 말했습니다.

민수는 고개를 끄덕이며 말했습니다. "할아버지, 시간이 정말 빠르죠? 그렇게 힘든 시기를 겪고 나서 지금까지 잘 지내신 것만으로도 대단한 일이에요. 그 시절의 이야기를 들려주셔서 정말 고마워요! 할아버지의 경험은 정말 소중한 것 같아요. 혹시 그때의 일들이 지금의 할아버지에게 어떤 영향을 주었는지도 궁금해요."

"그래, 그래. 나중에 또 들려줄게." 할아버지는 미소를 지으며 대답했습니다. "할아버지랑 또 재미있는 이야기 나누자꾸나."

"네, 할아버지!" 민수는 기뻐하며 대답했습니다. "다음에 또 재미있는 이야기 들려주세요! 할아버지의 이야기를 듣는 게 정말 즐거워요. 언제든지 기다리고 있을게요! 그럼 오늘도 행복한 하루 보내세요!"

그리고 그렇게 민수는 할아버지와 함께 소중한 기억을 나누며, 따뜻한 하루를 보냈습니다.
"""

# %%
import sys
sys.path.append("/Users/seongyeon/Desktop/K-digital/story_pocket/backend")  # 프로젝트 경로로 변경
from img.preprocessing import *

# %%
description = story_to_imgs_chain.invoke({"story": chat})

# %%
print(description)
# Out:
# #첫 번째 장면 묘사
# 부드러운 햇살이 비치는 한국의 시골 마을. 작은 소년 민수가 할아버지의 집으로 달려갑니다. 집은 전통적인 한옥으로, 푸른 잔디와 꽃으로 둘러싸여 있습니다.
#
# #두 번째 장면 묘사
# 민수는 할아버지를 안고 인사합니다. 할아버지는 흰머리에 따뜻한 미소를 지니고 있습니다. 두 사람은 함께 안락한 안방에서 앉아 있습니다. 방은 따뜻한 색조의 목재로 장식되어 있고, 창문에는 부드러운 햇살이 들어옵니다.
#
# #세 번째 장면 묘사
# 할아버지는 어린 시절 이야기를 시작합니다. 그는 6.25 전쟁으로 피난을 갔을 때의 일을 회상합니다. 흑백 사진이 화면에 나타나서 무너진 다리와 피난민들의 어려운 모습을 보여줍니다.
#
# #네 번째 장면 묘사
# 할아버지는 덜 익은 포도를 훔쳐 먹다가 배탈을 앓은 이야기를 합니다. 민수는 걱정스러운 표정으로 할아버지를 바라보며, 할아버지는 웃으며 이야기를 들려줍니다.
#
# #다섯 번째 장면 묘사
# 충청도에서 한 어르신이 꽁보리밥과 감자를 주신 이야기를 할아버지가 들려줍니다. 어르신의 따뜻한 미소와 감사하는 할아버지의 표정이 화면에 나타납니다.
#
# #여섯 번째 장면 묘사
# 민수와 할아버지는 이야기를 마칩니다. 민수는 고개를 끄덕이며 할아버지의 경험에 감동한 표정을 지니고 있습니다. 두 사람은 따뜻한 햇살 아래 함께 앉아 있습니다.

# %%
descriptions = description.split('\n\n')

# %%
prompts = []
for idx, description in enumerate(descriptions):
    prompt = description_to_prompt_chain.invoke({'description': description})
    prompts.append(prompt)
    # img = generate_image(story=description)

# %%
prompts = """
First scene prompt:
"A scenic rural Korean village under soft, warm sunlight, a young boy named Minsu runs towards his grandfather’s traditional Korean house (hanok), surrounded by green grass and blooming flowers. High-quality, wide-angle shot, soft lighting, ambient sunlight."

Second scene prompt:
"Minsu warmly hugs his grandfather with a soft, happy expression. The grandfather, with gray hair and a gentle smile, sits with him in a cozy, warm-toned living room decorated with traditional Korean wooden furniture. Soft sunlight filters through a nearby window, creating a serene and homely atmosphere. Medium shot, ambient lighting, high detail."

Third scene prompt:
"Grandfather recalls his childhood during the Korean War in a nostalgic black-and-white scene. A faded photo appears, showing a collapsed bridge with refugees gathered around, capturing the somber reality. High-detail monochrome image with a focus on emotional expression."

Fourth scene prompt:
"Grandfather, smiling softly, tells Minsu about a mischievous story of eating unripe grapes and suffering a stomachache. Minsu listens with a worried look on his face. Shot in warm lighting with a cinematic feel, close-up capture on the grandfather’s and Minsu’s expressions."

Fifth scene prompt:
"A iknd elderly man in Chungcheong Province shares barley and potatoes with a young grandfather. The elderly man's warm smile and the gratitude in the young grandfather's eyes are captured in the scene. Soft, ambient lighting, medium shot with a nostalgic, heartfelt tone."

Sixth scene prompt:
"As the story ends, Minsu sits by his grandfather’s side, touched by the stories he’s heard. Both sit together under soft, warm sunlight, Minsu nodding thoughtfully. Wide-angle shot with natural lighting, capturing the warm bond between them."
""".split('\n\n')

# %%
prompts
# Out:
# ['\nFirst scene prompt:\n"A scenic rural Korean village under soft, warm sunlight, a young boy named Minsu runs towards his grandfather’s traditional Korean house (hanok), surrounded by green grass and blooming flowers. High-quality, wide-angle shot, soft lighting, ambient sunlight."',
#  'Second scene prompt:\n"Minsu warmly hugs his grandfather with a soft, happy expression. The grandfather, with gray hair and a gentle smile, sits with him in a cozy, warm-toned living room decorated with traditional Korean wooden furniture. Soft sunlight filters through a nearby window, creating a serene and homely atmosphere. Medium shot, ambient lighting, high detail."',
#  'Third scene prompt:\n"Grandfather recalls his childhood during the Korean War in a nostalgic black-and-white scene. A faded photo appears, showing a collapsed bridge with refugees gathered around, capturing the somber reality. High-detail monochrome image with a focus on emotional expression."',
# ...

# %%
from img.tools import generate_image

# %%
prompts[0].split(':')[-1].strip('"\n')
# Out:
# 'A scenic rural Korean village under soft, warm sunlight, a young boy named Minsu runs towards his grandfather’s traditional Korean house (hanok), surrounded by green grass and blooming flowers. High-quality, wide-angle shot, soft lighting, ambient sunlight.'

# %%
# for prompt in prompts:
img = generate_image(story=prompts[0].split(':')[-1].strip('"\n'))
img.show()

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
print(descriptions[0])
print(prompts[0])
# Out:
# #첫 번째 장면 묘사
# 부드러운 햇살이 비치는 한국의 시골 마을. 작은 소년 민수가 할아버지의 집으로 달려갑니다. 집은 전통적인 한옥으로, 푸른 잔디와 꽃으로 둘러싸여 있습니다.
# Fairy tale style, a quaint rural village scene set in past Korea, with peaceful scenery and a warm color palette. The main focus is a young boy named Minsu, running towards his grandfather's house. The house is a traditional Hanok, surrounded by lush green grass and blooming flowers.

# %%
prompts[1].split(':')[-1].strip('"\n')
# Out:
# 'Minsu warmly hugs his grandfather with a soft, happy expression. The grandfather, with gray hair and a gentle smile, sits with him in a cozy, warm-toned living room decorated with traditional Korean wooden furniture. Soft sunlight filters through a nearby window, creating a serene and homely atmosphere. Medium shot, ambient lighting, high detail.'

# %%
# for prompt in prompts:
img = generate_image(story=prompts[1].split(':')[-1].strip('"\n'))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# for prompt in prompts:
img = generate_image(story=prompts[2].split(':')[-1].strip('"\n'))
img

# %%
# for prompt in prompts:
img = generate_image(story=prompts[1])
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# for prompt in prompts:
img = generate_image(story=prompts[3])
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
